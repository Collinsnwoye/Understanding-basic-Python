# %% [markdown]
# <a href="https://colab.research.google.com/github/Collinsnwoye/Understanding-basic-Python/blob/main/Copy_of_list_in_pyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pencil.
# Toy.
# Fruits.
# Pen.
# Rice.

# %%
item1="pencil"
item2="toy"
item3="fuits"
item4="pen"
item5="rice"
# Out:
# 'pencil'

# %%
items=["pencil","toy","fruits","pen","rice"]
items
# Out:
# ['pencil', 'toy', 'fruits', 'pen', 'rice']

# %%
items[0]
items=["pencil","toy","fruits","pen","rice"]
items
items[0]
items[0:2]
items[-1]
# Out:
# 'rice'

# %%
items[0]="chips"
items
# Out:
# ['chips', 'toy', 'fruits', 'pen', 'rice']

# %%
items.append("butter")
items
items=["chips","toy","fruits","pen","rice"]
items
items.append("butter")
items
items.insert(1,"juice")
items
# Out:
# ['chips', 'juice', 'toy', 'fruits', 'pen', 'rice', 'butter']

# %%
IT1=["pencil","toy","fruits","pen","rice"]
IT2=["cup","fish"]
items=IT1+IT2
items
# Out:
# ['pencil', 'toy', 'fruits', 'pen', 'rice', 'cup', 'fish']

# %%
items+"biscuit"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13759/3427000538.py in <cell line: 0>()
# ----> 1 items+"biscuit"
#
# TypeError: can only concatenate list (not "str") to list

# %%
len(items)
items
# Out:
# ['pencil', 'toy', 'fruits', 'pen', 'rice', 'cup', 'fish']

# %%
"pencil" in items
"ruler" in items
# Out:
# False
